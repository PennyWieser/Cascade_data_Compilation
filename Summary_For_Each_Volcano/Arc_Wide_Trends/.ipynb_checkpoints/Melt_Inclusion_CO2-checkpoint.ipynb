# %%
import pandas as pd
import numpy as np
import os
from os.path import splitext, basename
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
plt.style.use("seaborn-colorblind")
plt.rcParams["font.family"] = 'arial'
plt.rcParams["font.size"] =12
plt.rcParams["mathtext.default"] = "regular"
plt.rcParams["mathtext.fontset"] = "dejavusans"
plt.rcParams['patch.linewidth'] = 1
plt.rcParams['axes.linewidth'] = 1
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.size"] = 6 # Sets length of ticks
plt.rcParams["ytick.major.size"] = 4 # Sets length of ticks
plt.rcParams["ytick.labelsize"] = 12 # Sets size of numbers on tick marks
plt.rcParams["xtick.labelsize"] = 12 # Sets size of numbers on tick marks
plt.rcParams["axes.titlesize"] = 14 # Overall title
plt.rcParams["axes.labelsize"] = 14 # Axes labels

# %%
# Reads in the compiled dataset
dfm=pd.read_excel(r'../MeltInclusionCompilation_Sept22.xlsx')

# %%
dfm['H2O_Combo']=dfm['h2o_raw_wt']
has_PEC_data=dfm['h2o_pec_wt']>0
dfm.loc[has_PEC_data, 'H2O_Combo']=dfm['h2o_pec_wt']

dfm['SiO2_Combo']=dfm['sio2_raw_wt']
has_PEC_data=dfm['sio2_pec_wt']>0
dfm.loc[has_PEC_data, 'SiO2_Combo']=dfm['sio2_pec_wt']

# %%
plt.plot(dfm['satp_meash2omeasco2']/1000, dfm['xh2o_fl_meash2omeasco2'], 'or')
plt.xlim([0, 5])
plt.xlabel('Sat P (kbar)')
plt.ylabel('XH2O')
# Out:
# Text(0, 0.5, 'XH2O')

# %%
plt.plot(dfm['sio2_raw_wt'], dfm['xh2o_fl_meash2omeasco2'], '.r', label='No Raman')
plt.plot(dfm['sio2_raw_wt'], dfm['xh2o_fl_meash2oramanco2'], '*k', label='Raman')

plt.xlim([40, 80])
plt.xlabel('SiO2')
plt.ylabel('XH2O')
plt.legend()

# %%
plt.hist(dfm['xh2o_fl_meash2omeasco2'])
plt.xlabel('XH2O')
# Out:
# Text(0.5, 0, 'XH2O')

# %%
Baker_Lat=48.7767
Adams_Lat=46.2024
Glacier_Lat=48.1119
Rainier_Lat=46.8523

MSH_Lat=46.1914
Adams_Lat=46.2024
Hood_Lat=45.3736
Jefferson_Lat=44.6743
NorthSister_Lat=44.1662
SouthSister_Lat=44.1034
Sisters_Lat=44.13
CraterLake_Lat=42.85
Shasta_Lat=41.544
Lassen_Lat=40.654342
MedicineLake_Lat=41.6108
GVB_Lat=49.9366

# %%
fig, (ax1) = plt.subplots(1, figsize=(12,5))

s=ax1.scatter(dfm['latitude'], dfm['H2O_Combo'], marker='d', s=50, edgecolors='k', linewidths=0.5,
            c=dfm['SiO2_Combo'], cmap='hot',
vmin = 40, vmax = 75)
fig.colorbar(s, ax=ax1)
#fig.colorbar(cm.ScalarMappable(norm=norm, cmap=cmap), ax=ax1)
ax1.set_xticks([Lassen_Lat, Shasta_Lat, MedicineLake_Lat, CraterLake_Lat, Sisters_Lat, 
                Jefferson_Lat, Hood_Lat, MSH_Lat, Adams_Lat,
               Rainier_Lat, Glacier_Lat, Baker_Lat])
ax1.set_xticklabels(['Lassen', 'Shasta', 'Medicine Lake', 'Crater Lake', 'Sisters', 'Jefferson', 'Hood', 'MSH', 'Adams', 'Rainier',
                    'Glacier', 'Baker'], rotation=90)
# Out:
# [Text(40.654342, 0, 'Lassen'),
#  Text(41.544, 0, 'Shasta'),
#  Text(41.6108, 0, 'Medicine Lake'),
#  Text(42.85, 0, 'Crater Lake'),
#  Text(44.13, 0, 'Sisters'),
#  Text(44.6743, 0, 'Jefferson'),
#  Text(45.3736, 0, 'Hood'),
#  Text(46.1914, 0, 'MSH'),
#  Text(46.2024, 0, 'Adams'),
#  Text(46.8523, 0, 'Rainier'),
#  Text(48.1119, 0, 'Glacier'),
#  Text(48.7767, 0, 'Baker')]

# %%
dfm.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'reference', 'volcano', 'sample',
#        'host_mineral', 'mi_number', 'latitude', 'longitude',
#        'temperature_authors',
#        ...
#        'satp_meash2oramanco2', 'xh2o_fl_meash2oramanco2',
#        'satp_meash2otheorco2', 'xh2o_fl_meash2otheorco2',
#        'satp_diffh2omeasco2', 'xh2o_fl_diffh2omeasco2', 'satp_diffh2otheorco2',
#        'xh2o_fl_diffh2otheorco2', 'H2O_Combo', 'SiO2_Combo'],
#       dtype='object', length=160)

# %% [markdown]
# ## MAx 3 from each rounded latitude

# %%
dfm['volcano2']=dfm['volcano']
log_cen=dfm['volcano']=='CentralOregonMafics'
dfm.loc[log_cen, 'volcano2']=dfm['sample']
dfm['rounded_lat'] = dfm.apply(lambda row: str(round(row['latitude'], 1)) + row['volcano2'], axis=1)

# %%
# find le voyer ones
voyer=dfm['reference']=='LeVoyer_2010'
dfm.loc[voyer, 'rounded_lat']='41.5Shasta'

rusS=dfm['reference']=='Ruscitto_2011'
dfm.loc[rusS, 'rounded_lat']='41.5Shasta'

# find Yapoah ones 

rus=(dfm['reference']=='Ruscitto2010')&(dfm['sample'].str.contains('YAPOAH'))
dfm.loc[rus, 'rounded_lat']='44.2YAPOAH'

# Find two blue lake ones
joh_bl=(dfm['reference']=='Johnson2020')&(dfm['sample']=='Blue Lake Maar')
rus_bl=(dfm['reference']=='Ruscitto2011')&(dfm['sample']=='BL')

dfm.loc[(joh_bl|rus_bl), 'rounded_lat']='44.4BlueLake'

# %%
sum(rusS)
# Out:
# 20

# %%
dfm['volcano'].unique()
# Out:
# array(['Lassen', 'Mazama', 'Mount St. Helens', 'CentralOregonMafics',
#        'Mt Hood', 'Shasta', 'GlacierPeak', 'MountBaker', 'GarivaldiLake',
#        'MountCayley', 'MountMeager', 'SalalGlacier', 'BridgeRiver'],
#       dtype=object)

# %%
dfm['sample'].loc[dfm['reference']=='Ruscitto2010'].unique()
# Out:
# array(['Twin Craters', 'TC063Atop', 'Sand Mountain', 'PT05',
#        'YAPOAH Yo061E', 'YAPOAH Yo065D', 'COLLIER',
#        'GARRISON BUTTE CHAIN', 'Blue Lake Maar'], dtype=object)

# %%
for ref in dfm['rounded_lat'].unique():
    print('reference')
    print(ref)
    if ref==dfm['rounded_lat'].iloc[0]:
        df_b=dfm.loc[dfm['rounded_lat']==ref].reset_index(drop=True)
        largest=df_b['H2O_Combo'].nlargest(3).reset_index(drop=True)
        result1=df_b.loc[df_b['H2O_Combo']==largest[0]]
        result2=df_b.loc[df_b['H2O_Combo']==largest[1]]
        result3=df_b.loc[df_b['H2O_Combo']==largest[2]]
        combo_df=pd.concat([result1, result2], axis=0)
        combo_df_1=pd.concat([result1], axis=0)
        combo_df_2=pd.concat([result2], axis=0)
        combo_df_3=pd.concat([result3], axis=0)
    else:
        # result1 = dfm['H2O_Combo'].loc[dfm['reference']==ref].argsort()[::-1][0]
        # result2= dfm['H2O_Combo'].loc[dfm['reference']==ref].argsort()[::-1][1]
        # result3= dfm['H2O_Combo'].loc[dfm['reference']==ref].argsort()[::-1][2]
        # ref_df=dfm.loc[[result1, result2, result3]]        
        # combo_df=pd.concat([combo_df, ref_df])
        df_b=dfm.loc[dfm['rounded_lat']==ref].reset_index(drop=True)
        largest=df_b['H2O_Combo'].nlargest(3).reset_index(drop=True)
        result1=df_b.loc[df_b['H2O_Combo']==largest[0]]
        result2=df_b.loc[df_b['H2O_Combo']==largest[1]]
        #result3=df_b.loc[df_b['H2O_Combo']==largest[2]]
        if len(largest)>2:
            result3=df_b.loc[df_b['H2O_Combo']==largest[2]]
        else:
            result3=pd.DataFrame()
        ref_df=pd.concat([result1, result2], axis=0)
        combo_df_1=pd.concat([combo_df_1, result1])
        combo_df_2=pd.concat([combo_df_2, result2])
        combo_df_3=pd.concat([combo_df_3, result3])
        combo_df=pd.concat([combo_df, ref_df])
# Out:
# reference
# 40.7Lassen
# reference
# 40.5Lassen
# reference
# 42.9Mazama
# reference
# 46.2Mount St. Helens
# reference
# 44.4BL
# reference
# 45.4Mt Hood
# reference
# 41.5Shasta
# reference
# 42.6Mazama
# reference
# 44.3Twin Craters
# reference
# 44.3TC063Atop
# reference
# 44.4Sand Mountain
# reference
# 44.2PT05
# reference
# 44.2YAPOAH
# reference
# 44.2COLLIER
# reference
# 44.4GARRISON BUTTE CHAIN
# reference
# 44.4Blue Lake Maar
# reference
# 48.1GlacierPeak
# reference
# 48.8MountBaker
# reference
# 49.9GarivaldiLake
# reference
# 50.1MountCayley
# reference
# 50.6MountMeager
# reference
# 50.8SalalGlacier
# reference
# 50.8BridgeRiver
# reference
# 40.6Lassen
# reference
# 40.3Lassen

# %%
combo_df_1
# Out:
#          Unnamed: 0  Unnamed: 1                reference              volcano  \
# 33     Walowski2016          91            Walowski_2016               Lassen
# 34        Quinn2014          30               Quinn_2014               Lassen
# 101      Wright2012          91       Wright et al. 2012               Mazama
# 6        Blundy2010           6  Blundy et al. 2010 EPSL     Mount St. Helens
# 0       Johnson2020           0              Johnson2020  CentralOregonMafics
# 16     Koleszar2012          16            Koleszar_2012              Mt Hood
# 34     Ruscitto2011           9            Ruscitto_2011               Shasta
# 41   Mandeville2010          41   Mandeville et al. 2010               Mazama
# 4      Ruscitto2010           4             Ruscitto2010  CentralOregonMafics
# 1      Ruscitto2010           8             Ruscitto2010  CentralOregonMafics
# 2      Ruscitto2010          12             Ruscitto2010  CentralOregonMafics
# 7      Ruscitto2010          23             Ruscitto2010  CentralOregonMafics
# 3      Ruscitto2010          32             Ruscitto2010  CentralOregonMafics
# 2      Ruscitto2010          37             Ruscitto2010  CentralOregonMafics
# 5      Ruscitto2010          46             Ruscitto2010  CentralOregonMafics
# 2      Ruscitto2010          54             Ruscitto2010  CentralOregonMafics
# 11    Venugopal2020          11                 Shaw2011          GlacierPeak
# 1     Venugopal2020          17                 Shaw2011           MountBaker
# 4     Venugopal2020          28            Venugopal2020        GarivaldiLake
# 9     Venugopal2020          41            Venugopal2020          MountCayley
# 36    Venugopal2020          80            Venugopal2020          MountMeager
# 37    Venugopal2020          81            Venugopal2020          MountMeager
# 2     Venugopal2020          94            Venugopal2020         SalalGlacier
# 7     Venugopal2020         108            Venugopal2020          BridgeRiver
# 12    Venugopal2020         113            Venugopal2020          BridgeRiver
# 15     Walowski2016          31            Walowski_2016               Lassen
# 8      Walowski2016          64            Walowski_2016               Lassen
#
#                        sample   host_mineral         mi_number   latitude  \
# 33                       BORG        Olivine               A23  40.654342
# 34           LQ13-01-mi-27-01         Quartz  LQ13-01-mi-27-01  40.524000
# 101  rhyodacite of bear bluff  Orthopyroxene      1748OPX5-1.1  42.916500
# 6         1980-05-18 00:00:00    Plagioclase               NaN  46.191400
# 0                          BL        Olivine        1Ã¢Â€Â“3_1  44.425100
# 16              MH08-20-0210b            NaN               NaN  45.373600
# 34                   2S173-e1        Olivine               NaN  41.666000
# 41                 Llao rocks             nd            158#12  42.586300
# 4                Twin Craters        Olivine               1g2  44.254717
# 1                   TC063Atop        Olivine               1f1  44.254717
# 2               Sand Mountain        Olivine               1c1  44.394183
# 7                        PT05        Olivine               1g2  44.209050
# 3               YAPOAH Yo065D        Olivine              5Db2  44.215733
# 2                     COLLIER        Olivine               EJi  44.188400
# 5        GARRISON BUTTE CHAIN        Olivine                1f  44.387367
# 2              Blue Lake Maar        Olivine            BL16_1  44.408567
# 11                      IP001        Olivine             IP001  48.111900
# 1                       SM005        Olivine             SM005  48.776700
# 4                 CCD.1-1att2        Olivine       CCD.1-1att2  49.850700
# 9                  Cay18B.2-1        Olivine        Cay18B.2-1  50.120300
# 36                   MMAb9mi1        Olivine          MMAb9mi1  50.631700
# 37                  MMAb10mi3        Olivine         MMAb10mi3  50.631700
# 2                      SC3mi2        Olivine            SC3mi2  50.790000
# 7                      BR4mi2        Olivine            BR4mi2  50.750400
# 12                     BR7mi2        Olivine            BR7mi2  50.750400
# 15                        BRM        Olivine                 6  40.570325
# 8                        BPPC        Olivine                13  40.326172
#
#       longitude  temperature_authors  ...  satp_meash2otheorco2  \
# 33  -121.224742                  NaN  ...                   NaN
# 34  -121.522200                  NaN  ...                   NaN
# 101 -122.084500                883.0  ...                   NaN
# 6    122.195600                  NaN  ...                   NaN
# 0   -121.732900                  NaN  ...                4050.0
# 16   121.696000                  NaN  ...                   NaN
# 34  -122.030000                  NaN  ...                   NaN
# 41  -121.674300                880.0  ...                   NaN
# 33                 Lassen                40.7Lassen
# 34                 Lassen                40.5Lassen
# 101                Mazama                42.9Mazama
# 6        Mount St. Helens      46.2Mount St. Helens
# 0                      BL                    44.4BL
# 16                Mt Hood               45.4Mt Hood
# 34                 Shasta                41.5Shasta
# 41                 Mazama                42.6Mazama
# 4            Twin Craters          44.3Twin Craters
# 1               TC063Atop             44.3TC063Atop
# 2           Sand Mountain         44.4Sand Mountain
# 7                    PT05                  44.2PT05
# 3           YAPOAH Yo065D                44.2YAPOAH
# 2                 COLLIER               44.2COLLIER
# 5    GARRISON BUTTE CHAIN  44.4GARRISON BUTTE CHAIN
# 2          Blue Lake Maar        44.4Blue Lake Maar
# 11            GlacierPeak           48.1GlacierPeak
# 1              MountBaker            48.8MountBaker
# 4           GarivaldiLake         49.9GarivaldiLake
# 9             MountCayley           50.1MountCayley
# 36            MountMeager           50.6MountMeager
# 37            MountMeager           50.6MountMeager
# 2            SalalGlacier          50.8SalalGlacier
# 7             BridgeRiver           50.8BridgeRiver
# 12            BridgeRiver           50.8BridgeRiver
# 15                 Lassen                40.6Lassen
# 8                  Lassen                40.3Lassen
#
# [27 rows x 162 columns]

# %%
# dfm['reference_volc']=dfm["reference"]+dfm["volcano"]
# for ref in dfm['reference_volc'].unique():
#     print('reference')
#     print(ref)
#     if ref=="Aster_2016Lassen":
#         df_b=dfm.loc[dfm['reference_volc']==ref].reset_index(drop=True)
#         largest=df_b['H2O_Combo'].nlargest(3).reset_index(drop=True)
#         result1=df_b.loc[df_b['H2O_Combo']==largest[0]]
#         result2=df_b.loc[df_b['H2O_Combo']==largest[1]]
#         result3=df_b.loc[df_b['H2O_Combo']==largest[2]]
#         combo_df=pd.concat([result1, result2, result3], axis=0)
#     else:
#         # result1 = dfm['H2O_Combo'].loc[dfm['reference']==ref].argsort()[::-1][0]
#         # result2= dfm['H2O_Combo'].loc[dfm['reference']==ref].argsort()[::-1][1]
#         # result3= dfm['H2O_Combo'].loc[dfm['reference']==ref].argsort()[::-1][2]
#         # ref_df=dfm.loc[[result1, result2, result3]]        
#         # combo_df=pd.concat([combo_df, ref_df])
#         df_b=dfm.loc[dfm['reference_volc']==ref].reset_index(drop=True)
#         largest=df_b['H2O_Combo'].nlargest(3).reset_index(drop=True)
#         result1=df_b.loc[df_b['H2O_Combo']==largest[0]]
#         result2=df_b.loc[df_b['H2O_Combo']==largest[1]]
#         result3=df_b.loc[df_b['H2O_Combo']==largest[2]]
#         ref_df=pd.concat([result1, result2, result3], axis=0)
#         combo_df=pd.concat([combo_df, ref_df])

# %%
combo_df
# Out:
#          Unnamed: 0  Unnamed: 1                reference              volcano  \
# 33     Walowski2016          91            Walowski_2016               Lassen
# 29     Walowski2016          87            Walowski_2016               Lassen
# 34        Quinn2014          30               Quinn_2014               Lassen
# 15        Quinn2014          11               Quinn_2014               Lassen
# 101      Wright2012          91       Wright et al. 2012               Mazama
# 102      Wright2012          92       Wright et al. 2012               Mazama
# 6        Blundy2010           6  Blundy et al. 2010 EPSL     Mount St. Helens
# 1                     NaN                      NaN   0.800000    50.81000
# 9                     NaN                      NaN   0.900000    51.49000
# 10                    NaN                      NaN   0.600000    47.66000
# 36                    NaN                      NaN   3.100000    49.70000
# 37                    NaN                      NaN   3.100000    49.14000
# 36                    NaN                      NaN   3.100000    49.70000
# 37                    NaN                      NaN   3.100000    49.14000
# 2                     NaN                      NaN   1.600000    45.93000
# 5                     NaN                      NaN   1.500000    43.50000
# 8                     NaN                      NaN   1.500000    46.15000
# 7                     NaN                      NaN   1.400000    47.32000
# 12                    NaN                      NaN   1.400000    47.34000
# 7                     NaN                      NaN   1.400000    47.32000
# 12                    NaN                      NaN   1.400000    47.34000
# 15                    NaN                      NaN   2.970000    52.70000
# 25                    NaN                      NaN   2.570000    50.22000
# 8                     NaN                      NaN   2.850000    51.03000
# 3                     NaN                      NaN   2.540000    49.64000
#
#                  volcano2               rounded_lat
# 33                 Lassen                40.7Lassen
# 29                 Lassen                40.7Lassen
# 34                 Lassen                40.5Lassen
# 15                 Lassen                40.5Lassen
# 101                Mazama                42.9Mazama
# 102                Mazama                42.9Mazama
# 6        Mount St. Helens      46.2Mount St. Helens
# 1        Mount St. Helens      46.2Mount St. Helens
# 0                      BL                    44.4BL
# 6                      BL                    44.4BL
# 16                Mt Hood               45.4Mt Hood
# 25                Mt Hood               45.4Mt Hood
# 34                 Shasta                41.5Shasta
# 27                 Shasta                41.5Shasta
# 41                 Mazama                42.6Mazama
# 15                 Mazama                42.6Mazama
# 4            Twin Craters          44.3Twin Craters
# 0            Twin Craters          44.3Twin Craters
# 1               TC063Atop             44.3TC063Atop
# 2               TC063Atop             44.3TC063Atop
# 2           Sand Mountain         44.4Sand Mountain
# 4           Sand Mountain         44.4Sand Mountain
# 7                    PT05                  44.2PT05
# 3                    PT05                  44.2PT05
# 3           YAPOAH Yo065D                44.2YAPOAH
# 4           YAPOAH Yo065D                44.2YAPOAH
# 2                 COLLIER               44.2COLLIER
# 3                 COLLIER               44.2COLLIER
# 5    GARRISON BUTTE CHAIN  44.4GARRISON BUTTE CHAIN
# 9    GARRISON BUTTE CHAIN  44.4GARRISON BUTTE CHAIN
# 2          Blue Lake Maar        44.4Blue Lake Maar
# 5          Blue Lake Maar        44.4Blue Lake Maar
# 11            GlacierPeak           48.1GlacierPeak
# 3             GlacierPeak           48.1GlacierPeak
# 1              MountBaker            48.8MountBaker
# 2              MountBaker            48.8MountBaker
# 4           GarivaldiLake         49.9GarivaldiLake
# 1           GarivaldiLake         49.9GarivaldiLake
# 9             MountCayley           50.1MountCayley
# 10            MountCayley           50.1MountCayley
# 36            MountMeager           50.6MountMeager
# 37            MountMeager           50.6MountMeager
# 36            MountMeager           50.6MountMeager
# 37            MountMeager           50.6MountMeager
# 2            SalalGlacier          50.8SalalGlacier
# 5            SalalGlacier          50.8SalalGlacier
# 8            SalalGlacier          50.8SalalGlacier
# 7             BridgeRiver           50.8BridgeRiver
# 12            BridgeRiver           50.8BridgeRiver
# 7             BridgeRiver           50.8BridgeRiver
# 12            BridgeRiver           50.8BridgeRiver
# 15                 Lassen                40.6Lassen
# 25                 Lassen                40.6Lassen
# 8                  Lassen                40.3Lassen
# 3                  Lassen                40.3Lassen
#
# [55 rows x 162 columns]

# %%
fig, (ax1) = plt.subplots(1, figsize=(7,5))

s=ax1.scatter(combo_df['SiO2_Combo'], combo_df['H2O_Combo'], marker='d', s=50, edgecolors='k', linewidths=0.5,
            c=combo_df['SiO2_Combo'], cmap='hot',
vmin = 40, vmax = 75)
fig.colorbar(s, ax=ax1, label='SiO$_2$')
#fig.colorbar(cm.ScalarMappable(norm=norm, cmap=cmap), ax=ax1)#
ax1.set_xlabel('SiO$_2$ (wt%)')
ax1.set_ylabel('H$_2$O (wt%)')
fig.savefig('H2O_SiO2.png', dpi=200)

# %%
combo_df.to_clipboard(excel=True)

# %%
Baker_Lat=48.7767
Adams_Lat=46.2024
Glacier_Lat=48.1119
Rainier_Lat=46.8523

MSH_Lat=46.1914
Adams_Lat=46.2024
Hood_Lat=45.3736
Jefferson_Lat=44.6743
NorthSister_Lat=44.1662
SouthSister_Lat=44.1034
Sisters_Lat=44.13
CraterLake_Lat=42.85
Shasta_Lat=41.544
Lassen_Lat=40.654342
MedicineLake_Lat=41.6108
GVB_Lat=49.9366
Newberry_Lat=43.7221
MedicineLake_offset=0.1
offset=0.05
Adams_offset=0.2

# %%
fig, (ax1) = plt.subplots(1, figsize=(15,5))
ax1.plot(dfm['latitude'], dfm['H2O_Combo'], 'ok', mfc='grey', mec='grey', 
         ms=3,alpha=0.5, zorder=0 
         )
s=ax1.scatter(combo_df_1['latitude'], combo_df_1['H2O_Combo'], marker='d', s=70, edgecolors='k', linewidths=0.5,
            c=combo_df_1['SiO2_Combo'], cmap='hot_r',
vmin = 40, vmax = 75, zorder=101)
s=ax1.scatter(combo_df_2['latitude'], combo_df_2['H2O_Combo'], marker='<', s=40, edgecolors='k', linewidths=0.5,
            c=combo_df_2['SiO2_Combo'], cmap='hot_r',
vmin = 40, vmax = 75, zorder=101)
s=ax1.scatter(combo_df_3['latitude'], combo_df_3['H2O_Combo'], marker='o', s=20, edgecolors='k', linewidths=0.5,
            c=combo_df_3['SiO2_Combo'], cmap='hot_r',
vmin = 40, vmax = 75, zorder=101)
fig.colorbar(s, ax=ax1, label='SiO$_2$')
#fig.colorbar(cm.ScalarMappable(norm=norm, cmap=cmap), ax=ax1)
# ax1.set_xticks([Lassen_Lat, Shasta_Lat, MedicineLake_Lat, CraterLake_Lat, Sisters_Lat, 
#                 Jefferson_Lat, Hood_Lat, MSH_Lat, Adams_Lat,
#                Rainier_Lat, Glacier_Lat, Baker_Lat, GVB_Lat])
# ax1.set_xticklabels(['Lassen', 'Shasta', 'Medicine Lake', 'Crater Lake', 'Sisters', 'Jefferson', 'Hood', 'MSH', 'Adams', 'Rainier',
#                     'Glacier', 'Baker', 'GVB'], rotation=90)
#ax1.set_ylabel('H$_2$O (Max 3 MI per Study)')
ax1.set_xlim([40, 51])

# ax1.set_xticks([Lassen_Lat, Shasta_Lat, MedicineLake_Lat+MedicineLake_offset, CraterLake_Lat, Newberry_Lat, Sisters_Lat, 
#                 Jefferson_Lat, Hood_Lat, MSH_Lat+offset, Adams_Lat+Adams_offset+offset,
#                Rainier_Lat, Glacier_Lat, Baker_Lat])


# ax1.set_xticklabels(['Lassen', 'Shasta', 'Medicine Lake', 'Crater Lake', 'Newberry', 'Sisters', 'Jefferson', 'Hood', 'MSH', 'Adams', 'Rainier',
#                     'Glacier', 'Baker'], rotation=90)

#ax1.set_xticklabels([], rotation=90)
ax1.grid(color = 'k', linestyle = '--', axis='x',linewidth = 1, alpha = 0.1, zorder=0)
ax1.set_ylim([0, 7.5])
#ax1.set_xticks([40, 42, 44, 46, 48, 50])

fig.savefig('H2O_variations.png', dpi=200, transparent=True)

# %%
combo_df_1.loc[combo_df_1['latitude'].between(40, 41)]
# Out:
#       Unnamed: 0  Unnamed: 1      reference volcano            sample  \
# 33  Walowski2016          91  Walowski_2016  Lassen              BORG
# 34     Quinn2014          30     Quinn_2014  Lassen  LQ13-01-mi-27-01
# 15  Walowski2016          31  Walowski_2016  Lassen               BRM
# 8   Walowski2016          64  Walowski_2016  Lassen              BPPC
#
#    host_mineral         mi_number   latitude   longitude  temperature_authors  \
# 33      Olivine               A23  40.654342 -121.224742                  NaN
# 34       Quartz  LQ13-01-mi-27-01  40.524000 -121.522200                  NaN
# 15      Olivine                 6  40.570325 -121.592108                  NaN
# 8       Olivine                13  40.326172 -121.910733                  NaN
#
#     ...  satp_meash2otheorco2  xh2o_fl_meash2otheorco2  satp_diffh2omeasco2  \
# 33  ...                   NaN                      NaN                  NaN
# 34  ...                   NaN                      NaN                  NaN
# 15  ...                   NaN                      NaN                  NaN
# 8   ...                   NaN                      NaN                  NaN
#
#     xh2o_fl_diffh2omeasco2  satp_diffh2otheorco2  xh2o_fl_diffh2otheorco2  \
# 33                     NaN                   NaN                      NaN
# 34                     NaN                   NaN                      NaN
# 15                     NaN                   NaN                      NaN
# 8                      NaN                   NaN                      NaN
#
#     H2O_Combo  SiO2_Combo  volcano2  rounded_lat
# 33       3.34       48.70    Lassen   40.7Lassen
# 34       6.48       78.62    Lassen   40.5Lassen
# 15       2.97       52.70    Lassen   40.6Lassen
# 8        2.85       51.03    Lassen   40.3Lassen
#
# [4 rows x 162 columns]

# %%
combo_df_1.loc[combo_df_1['latitude'].between(41, 42)]
# Out:
#       Unnamed: 0  Unnamed: 1      reference volcano       sample host_mineral  \
# 22   LeVoyer2010          22   LeVoyer_2010  Shasta  samp. 95-15      Olivine
# 9   Ruscitto2011           9  Ruscitto_2011  Shasta     2S173-e1      Olivine
#
#    mi_number  latitude  longitude  temperature_authors  ...  \
# 22        12   41.3475   -122.167                  NaN  ...
# 9        NaN   41.6660   -122.030                  NaN  ...
#
#     satp_meash2otheorco2  xh2o_fl_meash2otheorco2  satp_diffh2omeasco2  \
# 22                   NaN                      NaN                  NaN
# 9                    NaN                      NaN                  NaN
#
#     xh2o_fl_diffh2omeasco2  satp_diffh2otheorco2  xh2o_fl_diffh2otheorco2  \
# 22                     NaN                   NaN                      NaN
# 9                      NaN                   NaN                      NaN
#
#     H2O_Combo  SiO2_Combo  volcano2  rounded_lat
# 22        2.6         NaN    Shasta   41.5Shasta
# 9         3.4       53.98    Shasta   41.7Shasta
#
# [2 rows x 162 columns]

# %%
combo_df_2.loc[combo_df_2['latitude'].between(41, 42)]
# Out:
#      Unnamed: 0  Unnamed: 1      reference volcano       sample host_mineral  \
# 6   LeVoyer2010           6   LeVoyer_2010  Shasta  samp. 85-1A      Olivine
# 2  Ruscitto2011           2  Ruscitto_2011  Shasta       S173-a      Olivine
#
#   mi_number  latitude  longitude  temperature_authors  ...  \
# 6       3C4    41.544   -122.279                  NaN  ...
# 2       NaN    41.666   -122.030                  NaN  ...
#
#    satp_meash2otheorco2  xh2o_fl_meash2otheorco2  satp_diffh2omeasco2  \
# 6                   NaN                      NaN                  NaN
# 2                   NaN                      NaN                  NaN
#
#    xh2o_fl_diffh2omeasco2  satp_diffh2otheorco2  xh2o_fl_diffh2otheorco2  \
# 6                     NaN                   NaN                      NaN
# 2                     NaN                   NaN                      NaN
#
#    H2O_Combo  SiO2_Combo  volcano2  rounded_lat
# 6       2.46       49.87    Shasta   41.5Shasta
# 2       3.34       59.13    Shasta   41.7Shasta
#
# [2 rows x 162 columns]

# %%
combo_df_3.loc[combo_df_3['latitude'].between(41, 42)]
# Out:
#       Unnamed: 0  Unnamed: 1      reference volcano       sample host_mineral  \
# 13   LeVoyer2010          13   LeVoyer_2010  Shasta  samp. 95-15      Olivine
# 7   Ruscitto2011           7  Ruscitto_2011  Shasta       S173-f      Olivine
#
#    mi_number  latitude  longitude  temperature_authors  ...  \
# 13       2I2   41.3475   -122.167                  NaN  ...
# 7        NaN   41.6660   -122.030                  NaN  ...
#
#     satp_meash2otheorco2  xh2o_fl_meash2otheorco2  satp_diffh2omeasco2  \
# 13                   NaN                      NaN                  NaN
# 7                    NaN                      NaN                  NaN
#
#     xh2o_fl_diffh2omeasco2  satp_diffh2otheorco2  xh2o_fl_diffh2otheorco2  \
# 13                     NaN                   NaN                      NaN
# 7                      NaN                   NaN                      NaN
#
#     H2O_Combo  SiO2_Combo  volcano2  rounded_lat
# 13       2.45       46.57    Shasta   41.5Shasta
# 7        3.17       53.72    Shasta   41.7Shasta
#
# [2 rows x 162 columns]

# %%
dfm['H2O_Combo'].loc[dfm['reference']=="Aster_2016"]
# Out:
# 0     2.0
# 1     1.7
# 2     1.5
# 3     1.6
# 4     1.3
# 5     0.8
# 6     1.5
# 7     0.8
# 8     0.6
# 9     0.1
# 10    1.5
# 11    1.1
# 12    0.4
# Name: H2O_Combo, dtype: float64

# %%
largest3=df_b['H2O_Combo'].nlargest(3)
largest3
# Out:
# 91    6.124139
# 92    6.075425
# 84    5.869876
# Name: H2O_Combo, dtype: float64

# %%
largest=df_b['H2O_Combo'].nlargest(3).reset_index(drop=True)
print(largest)
#df_b.loc[df_b['H2O_Combo']==largest]
# Out:
# 0    6.124139
# 1    6.075425
# 2    5.869876
# Name: H2O_Combo, dtype: float64
